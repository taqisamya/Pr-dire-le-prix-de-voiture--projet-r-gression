# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import openpyxl

# %%
df=pd.read_excel("..\data\data dictionary.xlsx")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\samya.taqi\AppData\Local\Temp\ipykernel_16184\1707731368.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df=pd.read_excel("..\data\data dictionary.xlsx")
#             Attribute                                        Description
# 0                Name                     The brand and model of the car
# 1            Location  The location in which the car is being sold or...
# 2                Year                   The year or edition of the model
# 3   Kilometers_Driven  The total kilometers driven in the car by the ...
# 4           Fuel_Type                   The type of fuel used by the car
# 5        Transmission           The type of transmission used by the car
# 6          Owner_Type  Whether the ownership is Firsthand, Second han...
# 7             Mileage  The standard mileage offered by the car compan...
# ...

# %%
df=pd.read_csv(r"..\data\train.csv", sep=",")
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df["Name"]=df["Name"].apply(lambda x: x.upper())
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               MARUTI WAGON R LXI CNG      Mumbai  2010              72000
# 1     HYUNDAI CRETA 1.6 CRDI SX OPTION        Pune  2015              41000
# 2                         HONDA JAZZ V     Chennai  2011              46000
# 3                    MARUTI ERTIGA VDI     Chennai  2012              87000
# 4      AUDI A4 NEW 2.0 TDI MULTITRONIC  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  MARUTI SWIFT VDI       Delhi  2014              27365
# 6015          HYUNDAI XCENT 1.1 CRDI S      Jaipur  2015             100000
# 6016             MAHINDRA XYLO D4 BSIV      Jaipur  2012              55000
# 6017                MARUTI WAGON R VXI     Kolkata  2013              46000
# 6018             CHEVROLET BEAT DIESEL   Hyderabad  2011              47000
#
# ...

# %%
# Extraire la marque
df["brand"] = df["Name"].str.split().str[0]
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               MARUTI WAGON R LXI CNG      Mumbai  2010              72000
# 1     HYUNDAI CRETA 1.6 CRDI SX OPTION        Pune  2015              41000
# 2                         HONDA JAZZ V     Chennai  2011              46000
# 3                    MARUTI ERTIGA VDI     Chennai  2012              87000
# 4      AUDI A4 NEW 2.0 TDI MULTITRONIC  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  MARUTI SWIFT VDI       Delhi  2014              27365
# 6015          HYUNDAI XCENT 1.1 CRDI S      Jaipur  2015             100000
# 6016             MAHINDRA XYLO D4 BSIV      Jaipur  2012              55000
# 6017                MARUTI WAGON R VXI     Kolkata  2013              46000
# 6018             CHEVROLET BEAT DIESEL   Hyderabad  2011              47000
#
# ...

# %%
# Extraire le modèle (1 ou 2 mots après la marque)
df["model"] = df["Name"].str.split().str[1:].str.join(" ")
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               MARUTI WAGON R LXI CNG      Mumbai  2010              72000
# 1     HYUNDAI CRETA 1.6 CRDI SX OPTION        Pune  2015              41000
# 2                         HONDA JAZZ V     Chennai  2011              46000
# 3                    MARUTI ERTIGA VDI     Chennai  2012              87000
# 4      AUDI A4 NEW 2.0 TDI MULTITRONIC  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  MARUTI SWIFT VDI       Delhi  2014              27365
# 6015          HYUNDAI XCENT 1.1 CRDI S      Jaipur  2015             100000
# 6016             MAHINDRA XYLO D4 BSIV      Jaipur  2012              55000
# 6017                MARUTI WAGON R VXI     Kolkata  2013              46000
# 6018             CHEVROLET BEAT DIESEL   Hyderabad  2011              47000
#
# ...

# %%
# Extraire le variant (le reste)
df["variant"] = df["Name"].str.split().str[3:].str.join(" ")
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               MARUTI WAGON R LXI CNG      Mumbai  2010              72000
# 1     HYUNDAI CRETA 1.6 CRDI SX OPTION        Pune  2015              41000
# 2                         HONDA JAZZ V     Chennai  2011              46000
# 3                    MARUTI ERTIGA VDI     Chennai  2012              87000
# 4      AUDI A4 NEW 2.0 TDI MULTITRONIC  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  MARUTI SWIFT VDI       Delhi  2014              27365
# 6015          HYUNDAI XCENT 1.1 CRDI S      Jaipur  2015             100000
# 6016             MAHINDRA XYLO D4 BSIV      Jaipur  2012              55000
# 6017                MARUTI WAGON R VXI     Kolkata  2013              46000
# 6018             CHEVROLET BEAT DIESEL   Hyderabad  2011              47000
#
# ...

# %%
df["Power"].sort_values().tail(20) #repérer les null et nan
# Out:
# 2668    NaN
# 2737    NaN
# 2780    NaN
# 2842    NaN
# 3272    NaN
# 3404    NaN
# 3520    NaN
# 3522    NaN
# 3810    NaN
# 4011    NaN
# 4152    NaN
# 4229    NaN
# 4577    NaN
# 4604    NaN
# 4697    NaN
# 4712    NaN
# 4952    NaN
# 5015    NaN
# 5185    NaN
# 5270    NaN
# Name: Power, dtype: str

# %%
df=df.replace(['null bhp'], np.nan)  #remplacer null par nan
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               MARUTI WAGON R LXI CNG      Mumbai  2010              72000
# 1     HYUNDAI CRETA 1.6 CRDI SX OPTION        Pune  2015              41000
# 2                         HONDA JAZZ V     Chennai  2011              46000
# 3                    MARUTI ERTIGA VDI     Chennai  2012              87000
# 4      AUDI A4 NEW 2.0 TDI MULTITRONIC  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  MARUTI SWIFT VDI       Delhi  2014              27365
# 6015          HYUNDAI XCENT 1.1 CRDI S      Jaipur  2015             100000
# 6016             MAHINDRA XYLO D4 BSIV      Jaipur  2012              55000
# 6017                MARUTI WAGON R VXI     Kolkata  2013              46000
# 6018             CHEVROLET BEAT DIESEL   Hyderabad  2011              47000
#
# ...

# %%
df["Power"].sort_values().tail()
# Out:
# 5873    NaN
# 5893    NaN
# 5925    NaN
# 5943    NaN
# 5985    NaN
# Name: Power, dtype: str

# %%
df.Power.isna().value_counts()
# Out:
# Power
# False    5876
# True      143
# Name: count, dtype: int64

# %%
df["Engine"].sort_values()
# Out:
# 2877    1047 CC
# 5625    1047 CC
# 4584    1047 CC
# 3077    1047 CC
# 292     1061 CC
#          ...
# 4712        NaN
# 4952        NaN
# 5015        NaN
# 5185        NaN
# 5270        NaN
# Name: Engine, Length: 6019, dtype: str

# %%
df.Engine.isna().value_counts()
# Out:
# Engine
# False    5983
# True       36
# Name: count, dtype: int64

# %%
data=df.drop(["Name","variant","New_Price","Location"], axis=1).copy() #conserve les références internes
data
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 6014  2014              27365    Diesel       Manual      First   28.4 kmpl
# 6015  2015             100000    Diesel       Manual      First   24.4 kmpl
# 6016  2012              55000    Diesel       Manual     Second   14.0 kmpl
# 6017  2013              46000    Petrol       Manual      First   18.9 kmpl
# 6018  2011              47000    Diesel       Manual      First  25.44 kmpl
#
# ...

# %%
# data.rename(columns={"Price": "target"}, inplace=True)
# data

# %%
data["Power"] = data["Power"].str.split().str[0]  #enlever les unités
data["Engine"] = data["Engine"].str.split().str[0]
data["Mileage"] = data["Mileage"].str.split().str[0]
data
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage  \
# 0     2010              72000       CNG       Manual      First    26.6
# 1     2015              41000    Diesel       Manual      First   19.67
# 2     2011              46000    Petrol       Manual      First    18.2
# 3     2012              87000    Diesel       Manual      First   20.77
# 4     2013              40670    Diesel    Automatic     Second    15.2
# ...    ...                ...       ...          ...        ...     ...
# 6014  2014              27365    Diesel       Manual      First    28.4
# 6015  2015             100000    Diesel       Manual      First    24.4
# 6016  2012              55000    Diesel       Manual     Second    14.0
# 6017  2013              46000    Petrol       Manual      First    18.9
# 6018  2011              47000    Diesel       Manual      First   25.44
#
#      Engine  Power  Seats  Price      brand                       model
# ...

# %%
# price_inr_to_euro=0.009267  # convertit roupies en euros 
# data["Price"]=data["Price"]*price_inr_to_euro*100000
# data

# %%
data.isnull().sum()
# Out:
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                36
# Power                143
# Seats                 42
# Price                  0
# brand                  0
# model                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               6019 non-null   int64
#  1   Kilometers_Driven  6019 non-null   int64
#  2   Fuel_Type          6019 non-null   str
#  3   Transmission       6019 non-null   str
#  4   Owner_Type         6019 non-null   str
#  5   Mileage            6017 non-null   object
#  6   Engine             5983 non-null   object
#  7   Power              5876 non-null   object
#  8   Seats              5977 non-null   float64
#  9   Price              6019 non-null   float64
#  10  brand              6019 non-null   object
#  11  model              6019 non-null   object
# dtypes: float64(2), int64(2), object(5), str(3)
# memory usage: 564.4+ KB

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %% [markdown]
# # les colonnes qui contiennet des valeurs manquentes

# %%
data["Mileage"] = pd.to_numeric(data["Mileage"], errors='coerce') #
data["Engine "] = pd.to_numeric(data["Engine"], errors='coerce')
data["Power"] = pd.to_numeric(data["Mileage"], errors='coerce')
data
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0     2010              72000       CNG       Manual      First    26.60
# 1     2015              41000    Diesel       Manual      First    19.67
# 2     2011              46000    Petrol       Manual      First    18.20
# 3     2012              87000    Diesel       Manual      First    20.77
# 4     2013              40670    Diesel    Automatic     Second    15.20
# ...    ...                ...       ...          ...        ...      ...
# 6014  2014              27365    Diesel       Manual      First    28.40
# 6015  2015             100000    Diesel       Manual      First    24.40
# 6016  2012              55000    Diesel       Manual     Second    14.00
# 6017  2013              46000    Petrol       Manual      First    18.90
# 6018  2011              47000    Diesel       Manual      First    25.44
#
#      Engine  Power  Seats  Price      brand                       model  \
# ...

# %%
data["Power"].isna().sum()
# Out:
# np.int64(2)

# %%
data["Power"].plot.box()
# Out:
# <Axes: >

# %%
data.Engine.isna().sum()
# Out:
# np.int64(36)

# %%
data = data.dropna(subset=["Engine"])
data.Engine.isna().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0     2010              72000       CNG       Manual      First    26.60
# 1     2015              41000    Diesel       Manual      First    19.67
# 2     2011              46000    Petrol       Manual      First    18.20
# 3     2012              87000    Diesel       Manual      First    20.77
# 4     2013              40670    Diesel    Automatic     Second    15.20
# ...    ...                ...       ...          ...        ...      ...
# 6014  2014              27365    Diesel       Manual      First    28.40
# 6015  2015             100000    Diesel       Manual      First    24.40
# 6016  2012              55000    Diesel       Manual     Second    14.00
# 6017  2013              46000    Petrol       Manual      First    18.90
# 6018  2011              47000    Diesel       Manual      First    25.44
#
#      Engine  Power  Seats  Price      brand                       model  \
# ...

# %%
data.to_csv("../data/pricecarnew.csv")

# %% [markdown]
# **Encodage**

# %%
# #convertit des données nominales aux valeurs numériques 1 2 3 4 5
# data["Location"]=pd.factorize(data["Location"])[0]
# data["Fuel_Type"]=pd.factorize(data["Fuel_Type"])[0]
# data["Transmission"]=pd.factorize(data["Transmission"])[0]
# data["Owner_Type"]=pd.factorize(data["Owner_Type"])[0]
# data["brand"]=pd.factorize(data["brand"])[0]
# data["model"]=pd.factorize(data["model"])[0]
# data

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5983 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               5983 non-null   int64
#  1   Kilometers_Driven  5983 non-null   int64
#  2   Fuel_Type          5983 non-null   str
#  3   Transmission       5983 non-null   str
#  4   Owner_Type         5983 non-null   str
#  5   Mileage            5981 non-null   float64
#  6   Engine             5983 non-null   object
#  7   Power              5981 non-null   float64
#  8   Seats              5977 non-null   float64
#  9   Price              5983 non-null   float64
#  10  brand              5983 non-null   object
#  11  model              5983 non-null   object
#  12  Engine             5983 non-null   float64
# dtypes: float64(5), int64(2), object(3), str(3)
# memory usage: 654.4+ KB

# %%
data.isnull().sum()
# Out:
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              2
# Engine               0
# Power                2
# Seats                6
# Price                0
# brand                0
# model                0
# Engine               0
# dtype: int64

# %% [markdown]
# # EDA

# %%
data.hist(bins=40,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Kilometers_Driven'}>,
#         <Axes: title={'center': 'Mileage'}>],
#        [<Axes: title={'center': 'Power'}>,
#         <Axes: title={'center': 'Seats'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Engine '}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
correlation=data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True ,cmap="coolwarm" , fmt=".2f", linewidths=0.5)
plt.title("la matrice de corrélation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 correlation=data.corr()
#       2 plt.figure(figsize=(10,8))
#       3 sns.heatmap(correlation, annot=True ,cmap="coolwarm" , fmt=".2f", linewidths=0.5)
#
# File c:\Users\samya.taqi\Desktop\SAMYA TAQI\Pr-dire-le-prix-de-voiture--projet-r-gression\price_car\pricecarenv\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
data["Engine"]=data["Engine"].astype(float)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\samya.taqi\Desktop\SAMYA TAQI\Pr-dire-le-prix-de-voiture--projet-r-gression\price_car\pricecarenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Engine'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.plot( kind='scatter', x="Engine", y="Transmission", alpha=0.1,c="Price", cmap=plt.get_cmap("jet"))
# Out:
# <Axes: xlabel='Engine', ylabel='Transmission'>

# %%
data.boxplot(column="Price", by="Transmission")
# Out:
# <Axes: title={'center': 'Price'}, xlabel='Transmission'>

# %%
plt.figure(figsize=(18,10))
correlation.drop("Price").plot(kind="bar")
plt.title("Feature Correlation with Target") 
plt.xlabel("correlation")
plt.show()

# %%
plt.figure()                                          # New figure
plt.scatter(data["Year"], data["Price"], s=2)  # Scatter MedInc vs target
plt.title("Year vs Price")                         # Title
plt.xlabel("Year")                                  # X label
plt.ylabel("Price")                                  # Y label
plt.show()

# %%
# data.drop('Engine', axis=1, inplace=True)
# data
colonne_supprimer=[ 'Seats', 'Location']
data=data.drop(colonne_supprimer, axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 4
#       1 # data.drop('Engine', axis=1, inplace=True)
#       2 # data
#       3 colonne_supprimer=[ 'Seats', 'Location']
# ----> 4 data=data.drop(colonne_supprimer, axis=1)
#       5 data
#
# File c:\Users\samya.taqi\Desktop\SAMYA TAQI\Pr-dire-le-prix-de-voiture--projet-r-gression\price_car\pricecarenv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
# ...

# %%
data.to_csv("../data/pricecarnew.csv")

# %%
from sklearn.pipeline import Pipeline                  # Pipeline to prevent leakage
from sklearn.compose import ColumnTransformer          # Different preprocessing per column type
from sklearn.preprocessing import StandardScaler       # Feature scaling (important for SVR)
from sklearn.preprocessing import OneHotEncoder        # Convert categorical to one-hot vectors
from sklearn.impute import SimpleImputer 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  , Lasso    # Multivariable regression model
from sklearn.svm import SVR                            # Support Vector Regression model
from sklearn.metrics import mean_absolute_error, mean_squared_error , r2_score , classification_report 
from sklearn.preprocessing import RobustScaler

# %%
x=data.drop(columns=["Price"]) #features
y=data["Price"] #cible

# %%
#séparer les différents types de données
numeric_features = x.select_dtypes(include=[np.number]).columns.tolist()   # Numeric columns list.tolist()  
categorical_features = x.select_dtypes(exclude=[np.number]).columns.tolist()  # Categorical columns list

# %%
numeric_features
# Out:
# ['Year',
#  'Kilometers_Driven',
#  'Fuel_Type',
#  'Transmission',
#  'Owner_Type',
#  'Mileage',
#  'Power',
#  'brand',
#  'model',
#  'Engine ']

# %%
categorical_features
# Out:
# []

# %%
data["Power"] = data["Power"].fillna(data["Power"].median()) #imputer
data["Mileage"]=data["Mileage"].fillna(data["Mileage"].median())
data
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0     2010              72000       CNG       Manual      First    26.60
# 1     2015              41000    Diesel       Manual      First    19.67
# 2     2011              46000    Petrol       Manual      First    18.20
# 3     2012              87000    Diesel       Manual      First    20.77
# 4     2013              40670    Diesel    Automatic     Second    15.20
# ...    ...                ...       ...          ...        ...      ...
# 6014  2014              27365    Diesel       Manual      First    28.40
# 6015  2015             100000    Diesel       Manual      First    24.40
# 6016  2012              55000    Diesel       Manual     Second    14.00
# 6017  2013              46000    Petrol       Manual      First    18.90
# 6018  2011              47000    Diesel       Manual      First    25.44
#
#       Power  Price      brand        model  Engine
# ...

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),     # Fill missing numeric values with median (computed on TRAIN only)
    ("scaler", StandardScaler())                       # Standardize features (fit on TRAIN only)
])

# %%
categorical_transformer=Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# %%
data.Mileage.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Entrainement de modèle

# %%
# Diviser les données en ensembles d'entraînement et de test

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Créer et entraîner le modèle de régression linéaire
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Faire des prédictions sur l'ensemble de test
y_pred = model.predict(x_test)

# Évaluer les performances du modèle
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"MSE= {mse:.2f}")
print(f"R² = {r2:.2f}")
# Out:
# MSE= 40267814.71
# R² = 0.60

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score

# Créer le modèle Lasso
lasso = Lasso(alpha=0.1)  # alpha = niveau de régularisation

# Entraîner le modèle
lasso.fit(x_train, y_train)

# Faire des prédictions
y_pred = lasso.predict(x_test)

# Évaluer
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MSE = {mse:.2f}")
print(f"R²  = {r2:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 lasso = Lasso(alpha=0.1)  # alpha = niveau de régularisation
#       7 # Entraîner le modèle
# ----> 8 lasso.fit(x_train, y_train)
#      10 # Faire des prédictions
#      11 y_pred = lasso.predict(x_test)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.model_selection import GridSearchCV

params = {'alpha': [0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(Lasso(), params, cv=5)
grid.fit(x_train, y_train)
print("Meilleur alpha :", grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.model_selection import GridSearchCV
#       3 params = {'alpha': [0.001, 0.01, 0.1, 1, 10]}
# ----> 4 grid = GridSearchCV(Lasso(), params, cv=5)
#       5 grid.fit(x_train, y_train)
#       6 print("Meilleur alpha :", grid.best_params_)
#
# NameError: name 'Lasso' is not defined
