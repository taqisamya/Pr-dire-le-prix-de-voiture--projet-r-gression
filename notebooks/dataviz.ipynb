# %%
import numpy as np                           
import pandas as pd                                 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("..\\data\\train_clean.csv")
data.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0      Mumbai  2010              72000       CNG       Manual      First
# 1        Pune  2015              41000    Diesel       Manual      First
# 2     Chennai  2011              46000    Petrol       Manual      First
# 3     Chennai  2012              87000    Diesel       Manual      First
# 4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#    Mileage  Power  Price    Brand                       Model
# 0     26.0   58.0   1.75   MARUTI             WAGON R LXI CNG
# 1     19.0  126.0  12.50  HYUNDAI    CRETA 1.6 CRDI SX OPTION
# 2     18.0   88.0   4.50    HONDA                      JAZZ V
# 3     20.0   88.0   6.00   MARUTI                  ERTIGA VDI
# 4     15.0  140.0  17.74     AUDI  A4 NEW 2.0 TDI MULTITRONIC
